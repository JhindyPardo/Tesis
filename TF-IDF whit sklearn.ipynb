# %%
import pandas as pd
import numpy as np
import operator
import string
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.data import load
from nltk.stem import SnowballStemmer
from string import punctuation
import re

#LEER EL DATASET

df=pd.read_csv('Dataset.csv')
#L=np.asarray(df)
#print(L)

data = pd.read_csv("Dataset.csv", sep=",")
Tweet = data[["Tweet"]]
T=np.asarray(Tweet)
processed_tweets =[]

##########################################
punctuation = list(string.punctuation)
stemmer = SnowballStemmer("spanish")
stop = stopwords.words('spanish') + punctuation
vc = TfidfVectorizer()
#############Documentos##################
documentA = str(T[55])
print(str(T[55]))
documentB = str(T[57])
########################################
emoticons_str = r"""
    (?:
        [:=;] # :(
        [oO\-]? # No se
        [D\)\]\(\]/\\OpP] # 
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
##############Metodos####################



def generate_ngrams(s, n):
    # Convert to lowercases
    s = s.lower()
    # Romper la oración en el tokens
    tokens_first = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE )
    tokens = tokens_first.findall(s)
        
    # eliminar tokens vacíos, links, menciones, stopwords y hastags
    tokens = [token for token in tokens if (token != "" ) and (token not in stop) and (not token.startswith(('#', '@', 'https:', 'http:')))]
    #lematizar
    tokens = [stemmer.stem(token) for token in tokens]
    # print(tokens)
    # funcion zip genera n-grams
    # Concatena los tokens en los ngrams y los retorna
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict


def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict

def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

#########################################

##########Preprocesamiento##########
n=2
unique = [' ']
for tweet in T:
    bagOfWords = generate_ngrams(str(tweet), n)
    unique = set(unique).union(set(bagOfWords))
    processed_tweets.append(bagOfWords)
for tweet in T:
    numOfWords = dict.fromkeys(uniqueWords, 0)

# vectorizer = TfidfVectorizer (max_features=2500, min_df=7, max_df=0.8)
# processed_features = vectorizer.fit_transform(processed_tweets).toarray()
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
print(processed_tweets)
# Out:
# [['argument muestrem', 'muestrem dios', 'dios polit', 'polit habl', 'habl polici', 'polici muert', 'muert atent', 'atent santand', 'santand lleg', 'lleg vot', 'vot jep', 'jep favorec', 'favorec nin', 'nin victim', 'victim farc', 'farc aqui', 'aqui debat', 'debat usted', 'usted sab', 'sab verd', 'verd quier', 'quier defend', 'defend indefend'], ['constituyent arruin', 'arruin acuerd', 'acuerd paz', 'paz jep', 'jep asi', 'asi simpl'], ['buen notici'], ['seri sistem', 'sistem democrat', 'democrat separacion', 'separacion poder', 'poder president', 'president duqu', 'duqu gobiern', 'gobiern unic', 'unic respons', 'respons si', 'si vam', 'vam dialog', 'dialog hor', 'hor llam', 'llam cuent', 'cuent congres', 'congres pod', 'pod judicial', 'judicial jep', 'jep inclu', 'inclu ciudadan', 'ciudadan exig', 'exig trabaj', 'trabaj bien'], ['si podri', 'podri dos', 'dos maner', 'maner aguil', 'aguil destru', 'destru jep', 'jep quem', 'quem hac', 'hac guerr', 'guerr ello', 'ello pediri', 'pediri urib', 'urib hag', 'hag constituyent', 'constituyent ataqu', 'ataqu venezuel', 'venezuel quem', 'quem derrit', 'derrit absorb'], ['cinism sant', 'sant viv', 'viv colombi', 'colombi extendi', 'extendi guerrill', 'guerrill pais', 'pais dio', 'dio monton', 'monton curul', 'curul asesin', 'asesin queri', 'queri mayor', 'mayor presupuest', 'presupuest jep'], ['convoc asambl', 'asambl aconstituyent', 'aconstituyent necesari', 'necesari seri', 'seri complement', 'complement acuerd', 'acuerd esper', 'esper inclu', 'inclu blind', 'blind constitucion', 'constitucion promes', 'promes dio', 'dio sant', 'sant reform', 'reform agrari', 'agrari desmovilizacion', 'desmovilizacion grup', 'grup proteg', 'proteg jep', 'jep parec', 'parec acert'], ['jod q', 'q usted', 'usted sab', 'sab sab', 'sab q', 'q q', 'q necesit', 'necesit urib', 'urib salv', 'salv acab', 'acab jep', 'jep constituyent', 'constituyent dig', 'dig q', 'q usted', 'usted sali', 'sali paquet', 'paquet chilen'], ['si dan', 'dan papay', 'papay primer', 'primer hac', 'hac acab', 'acab acuerd', 'acuerd paz', 'paz jep'], ['loc constituyent', 'constituyent entreg', 'entreg jep', 'jep urib', 'urib entreg', 'entreg gan', 'gan derech', 'derech elit', 'elit entreg', 'entreg futur', 'futur clas', 'clas polit', 'polit acab', 'acab poquit', 'poquit pais'], ['amad sentenci', 'sentenci muert', 'muert qued', 'qued sombr', 'sombr acab', 'acab siempr', 'siempr jep'], ['asamble constituyent', 'constituyent muert', 'muert polit', 'polit corrupt', 'corrupt acab', 'acab jep', 'jep cort', 'cort asesin', 'asesin pedofil', 'pedofil congres', 'congres reduzc', 'reduzc sueld', 'sueld numer', 'numer congres', 'congres ala', 'ala mit', 'mit narcoterror', 'narcoterror delit', 'delit gravisim'], ['sab si', 'si ven', 'ven pid', 'pid constituyent', 'constituyent dej', 'dej segu', 'segu si', 'si sid', 'sid secuestr', 'secuestr amo', 'amo jep'], ['paramilit urib', 'urib tiemp', 'tiemp fascism', 'fascism acab', 'acab amig', 'amig paz', 'paz encim', 'encim usted', 'usted q', 'q quier', 'quier dan', 'dan q', 'q viv', 'viv jep'], ['constituyent sol', 'sol ser', 'ser enmend', 'enmend repon', 'repon q', 'q quit', 'quit constitucion', 'constitucion sintesis', 'sintesis social', 'social derech'], ['renunci constituyent', 'constituyent otorg', 'otorg mayor', 'mayor presupuest', 'presupuest jep', 'jep mas', 'mas curul', 'curul farc', 'farc cumplimient', 'cumplimient exeget', 'exeget acuerd', 'acuerd guerrill', 'guerrill reinici', 'reinici dialog', 'dialog grup', 'grup armad', 'armad ilegal'], ['propuest contraproducent', 'contraproducent abre', 'abre puert', 'puert tumb', 'tumb jep', 'jep ser', 'ser tambi', 'tambi hac', 'hac lobby', 'lobby urib'], ['pap acogi', 'acogi jep'], ['import cu', 'cu ahorit', 'ahorit result', 'result farc', 'farc jep', 'jep libr', 'libr santiam'], ['cacerolaz tal', 'tal jep'], ['hac par', 'par caus', 'caus desconoc', 'desconoc apuest', 'apuest si', 'si ped', 'ped firm', 'firm derog', 'derog reduc', 'reduc congres', 'congr ...
