# %%
import pandas as pd
import numpy as np
import operator
import string
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.corpus import stopwords
from nltk import word_tokenize
from nltk.data import load
from nltk.stem import SnowballStemmer
from string import punctuation
import re

#LEER EL DATASET

df=pd.read_csv('Dataset.csv')
#L=np.asarray(df)
#print(L)

data = pd.read_csv("Dataset.csv", sep=",")
##########################################
punctuation = list(string.punctuation)
stemmer = SnowballStemmer("spanish")
stop = stopwords.words('spanish') + punctuation
vc = TfidfVectorizer()
#############Documentos##################
Tweet = data[["Tweet"]]
T=np.asarray(Tweet)
bigNumOfWords = []
########################################
emoticons_str = r"""
    (?:
        [:=;] # :(
        [oO\-]? # No se
        [D\)\]\(\]/\\OpP] # 
    )"""
 
regex_str = [
    emoticons_str,
    r'<[^>]+>', # HTML tags
    r'(?:@[\w_]+)', # @-mentions
    r"(?:\#+[\w_]+[\w\'_\-]*[\w_]+)", # hash-tags
    r'http[s]?://(?:[a-z]|[0-9]|[$-_@.&amp;+]|[!*\(\),]|(?:%[0-9a-f][0-9a-f]))+', # URLs
 
    r'(?:(?:\d+,?)+(?:\.?\d+)?)', # numbers
    r"(?:[a-z][a-z'\-_]+[a-z])", # words with - and '
    r'(?:[\w_]+)', # other words
    r'(?:\S)' # anything else
]
##############Metodos####################



def generate_ngrams(s, n):
    # Convert to lowercases
    s = s.lower()
    # Romper la oración en el tokens
    tokens_first = re.compile(r'('+'|'.join(regex_str)+')', re.VERBOSE | re.IGNORECASE )
    tokens = tokens_first.findall(s)
        
    # eliminar tokens vacíos, links, menciones, stopwords y hastags
    tokens = [token for token in tokens if (token != "" ) and (token not in stop) and (not token.startswith(('#', '@', 'https:', 'http:')))]
    #lematizar
    tokens = [stemmer.stem(token) for token in tokens]
    # print(tokens)
    # funcion zip genera n-grams
    # Concatena los tokens en los ngrams y los retorna
    ngrams = zip(*[tokens[i:] for i in range(n)])
    return [" ".join(ngram) for ngram in ngrams]

def computeTF(wordDict, bagOfWords):
    tfDict = {}
    bagOfWordsCount = len(bagOfWords)
    
    for word, count in wordDict.items():
        if bagOfWordsCount != 0:
            tfDict[word] = count / float(bagOfWordsCount)
    return tfDict


def computeIDF(documents):
    import math
    N = len(documents)
    print(N)
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    
    for document in documents:
        for word, val in document.items():
            
            if val > 0:
                idfDict[word] += 1
    for word, val in idfDict.items():
        if val != 0:
            idfDict[word] = math.log(N / float(val))
    return idfDict

def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

#########################################

##########Preprocesamiento##########
n=1
unique = [' ']
count = 0
count2 = 0
bigBagOfWords = []
for tweet in T:
    bagOfWords = generate_ngrams(str(tweet), n)
    unique = set(unique).union(set(bagOfWords))
    bigBagOfWords.insert(0, bagOfWords)

for tweet in bigBagOfWords:
    numOfWords = dict.fromkeys(unique, 0)
    for word in item:
        numOfWords[word] += 1
    bigNumOfWords.append(numOfWords)

count = 0
bigTf = {}
bigTfidf= []
for tweet in T:
    tf = computeTF(bigNumOfWords[count], bigBagOfWords[count])
    bigTf[count] = tf
    count += 1
idfs = computeIDF(bigNumOfWords)
for tweet in T:
    bigTfidf.append(computeTFIDF(bigTf[count2], idfs))
    count2 += 1
df = pd.DataFrame(bigTfidf)

# %%
print(bigBagOfWords[0])
# Out:
# ['espos llev', 'llev siniestr', 'siniestr juan', 'juan manuel', 'manuel sant', 'sant desvergonz', 'desvergonz jep', 'jep emolument', 'emolument 17', '17 millon', 'millon mensual', 'mensual sum', 'sum 33', '33 deveng', 'deveng pc3', 'pc3 ceped', 'ceped lleg', 'lleg mont', 'mont 50', '50 milloncit', 'milloncit mensual']

# %%
print(bigNumOfWords[0])
# Out:
ri hiz': 0.0, 'frent jep': 0.0, 'si ped': 0.0, 'acab pes': 0.0, 'product transform': 0.0, 'arrebat farc': 0.0, 'ten pued': 0.0, 'polit justici': 0.0, '7 delit': 0.0, 'nunc guerrill': 0.0, 'respons d': 0.0, 'especial paz': 0.0, 'cuent siqu': 0.0, 'jep gral': 0.0, 'pas oblig': 0.0, 'siii ayud': 0.0, 'aport lt': 0.0, 'colombian jep': 0.0, 'mon mancuss': 0.0, 'cd davil': 0.0, 'iba acab': 0.0, 'matador ernest': 0.0, 'bien urib': 0.0, 'sr urib': 0.0, 'primer sesion': 0.0, 'paz vuelv': 0.0, 'orquest propi': 0.0, 'bandaz cas': 0.0, 'justici adquier': 0.0, 'capitul histori': 0.0, 'aguant cervez': 0.0, 'curul impun': 0.0, 'mecan degl': 0.0, 'colombi dich': 0.0, 'sangr mism': 0.0, 'paz mejor': 0.0, 'quier asesin': 0.0, 'mas tem': 0.0, 'part polit': 0.0, 'cit president': 0.0, 'estrategi dar': 0.0, 'mism logic': 0.0, 'fos comun': 0.0, 'cabez izquird': 0.0, 'carcel deshonest': 0.0, 'tiemp auv': 0.0, 'jep jurisdiccion': 0.0, 'llames jep': 0.0, 'ordinari 10': 0.0, 'jep liber': 0.0, 'senorit atac': 0.0, 'realid pued': 0.0, 'lanz candidatur': 0.0, 'afor excongres': 0.0, 'moment demostr': 0.0, 'demand impuest': 0.0, 'amig veo': 0.0, 'futur clas': 0.0, 'plebiscit odebrech': 0.0, 'salvav sal': 0.0, 'nacional minim': 0.0, 'declar benefici': 0.0, 'ivan marquez': 0.0, 'luj urib': 0.0, 'defensor ofici': 0.0, 'quem hac': 0.0, 'salud abus': 0.0, 'vid trabaj': 0.0, 'orden rodrig': 0.0, 'perfect jep': 0.0, 'dir antoj': 0.0, 'dich promes': 0.0, 'maner aport': 0.0, 'verd ello': 0.0, 'aqui apropi': 0.0, 'colombi polit': 0.0, 'mas hp': 0.0, 'ahor nuev': 0.0, 'constitucion ley': 0.0, 'hij mas': 0.0, 'ver dij': 0.0, 'malnac da': 0.0, 'band farc': 0.0, 'conflict gent': 0.0, 'etc ento ...

# %%
print(df)
# Out:
#                   Date                                              Tweet  \
# 0      25/11/2019 0:10  @Manuel21160307 @eavfch @JDrestrepoU @alexdavi...
# 1      25/11/2019 0:09  Con la constituyente arruinan el acuerdo de pa...
# 2      25/11/2019 0:09  @herbinhoyos @Registraduria @JEP_Colombia Muy ...
# 3      25/11/2019 0:08  Seamos serios: en un sistema democratico, con ...
# 4      25/11/2019 0:06  Si podria hay dos maneras El aguila destruya l...
# ...                ...                                                ...
# 2125  16/02/2020 11:00  El equipo forense de la JEP removio la tierra ...
# 2126  16/02/2020 10:55  @NachoGomex Es la costumbre del Estado, record...
# 2127  16/02/2020 10:53  La costumbre,falsos positivos judiciales,crime...
# 2128  16/02/2020 10:23  Apoyan asesinato de bebe de 7 meses de gestaci...
# 2129  16/02/2020 10:23  Y esa esposa la llevo el siniestro Juan Manuel...
#
#       Label
# 0       2.0
# 1       0.0
# 2       1.0
# 3       0.0
# 4       2.0
# ...     ...
# 2125    NaN
# 2126    NaN
# 2127    NaN
# 2128    NaN
# 2129    NaN
#
# [2130 rows x 3 columns]
